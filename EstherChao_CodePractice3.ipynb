# %% [markdown]
# ## Esther Chao | Data Bootcamp: Code Practice 3

# %% [markdown]
# ### 1. Enter and run this code in a Jupyter cell to produce the dataframe weo:

# %%
import pandas as pd
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
        'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
        'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
        'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)

# %%
weo
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# **a. Explain the ```import``` statement.**

# %% [markdown]
# The import statement tells Python which packages we plan to use. In this case, our statement imports the data package Pandas under the abbreviation pd.

# %% [markdown]
# **b. What type of object is ```data?```**

# %%
type(data) # Data is a dictionary, shown by the curly brackets.
# Out:
# dict

# %% [markdown]
# **c. Why does the last line have ```pd``` prior to the ```DataFrame``` function?**

# %% [markdown]
# We imported Pandas into the the program under the abbrevation pd. Thus, since the ```DataFrame``` function lies within Pandas, we have to call the package first by adding ```pd``` prior to the function.

# %% [markdown]
# **d. What type of object is ```weo```?**

# %%
type(weo) # weo is a DataFrame; the text prior to DataFrame just tells us some things about where this type lives within pandas.
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **e. How many rows does it have? Columns?**

# %%
weo.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
len(weo.index.tolist()) # weo has seven rows, referred to as the index by Pandas.
# Out:
# 7

# %%
weo.columns.tolist()
# Out:
# ['BRA', 'JPN', 'USA', 'Year']

# %%
len(weo.columns.tolist()) # weo has four columns.
# Out:
# 4

# %% [markdown]
# **f. What ```dtypes``` are the variables/columns? What does this mean?**

# %%
weo.dtypes
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %% [markdown]
# The variables for the BRA, JPN and USA columns are all floats, meaning numbers with decimals. However, year is an integer because its variables are whole numbers and don't have decimal points.

# %% [markdown]
# **g. *Challenging.* What are each of these expressions? What type?**

# %%
weo['Year'] # This expression extracts only the column Year from the data set.
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %%
type(weo['Year']) # It is a series, which is essentially a DataFrame with a single variable or column.
# Out:
# pandas.core.series.Series

# %%
weo[['Year']] # This expression also extracts only the column Year from the data set but neatly formatted.
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %%
type(weo[['Year']]) # It is a DataFrame, indicated by the double brackets used when we ask for multiple variables.
# Out:
# pandas.core.frame.DataFrame

# %%
weo[[3]] # Calling a column by its number no longer works in this version.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-15de6f990b15> in <module>()
# ----> 1 weo[[3]] # Calling a column by its number no longer works in this version.
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ...

# %% [markdown]
# **h. *Challenging.* Find and apply a method to convert ```weo['Year']``` to type float. *Hint:* The method begins with the letter a.**

# %%
weo['Year']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %%
weo['Year'] = weo.Year.astype('float64')

# %%
weo['Year']
# Out:
# 0    2008.0
# 1    2009.0
# 2    2010.0
# 3    2011.0
# 4    2012.0
# 5    2013.0
# 6    2014.0
# Name: Year, dtype: float64

# %% [markdown]
# **i. Describe the result of the statement ```t = weo.tail(3)```. What kind of object is t? What does it look like?**

# %%
t = weo.tail(3)

# %%
type(t)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The statement ```weo.tail(3)```extracts the bottom 3 observations to create a new DataFrame. It looks like this:

# %%
t
# Out:
#      BRA    JPN    USA    Year
# 4  15.46  35.60  51.41  2012.0
# 5  15.98  36.79  52.94  2013.0
# 6  16.10  37.39  54.60  2014.0

# %% [markdown]
# **j. How would you create a new dataframe that consists of the first 4 rows of weo?**

# %%
h = weo.head(4)

# %%
h
# Out:
#      BRA    JPN    USA    Year
# 0  13.37  33.43  48.30  2008.0
# 1  13.30  31.83  46.91  2009.0
# 2  14.34  33.71  48.31  2010.0
# 3  15.07  34.29  49.72  2011.0

# %% [markdown]
# **k. What type of object is ```weo['BRA']```?**

# %%
weo['BRA']
# Out:
# 0    13.37
# 1    13.30
# 2    14.34
# 3    15.07
# 4    15.46
# 5    15.98
# 6    16.10
# Name: BRA, dtype: float64

# %%
type(weo['BRA']) # It is a series, which is essentially a DataFrame with a single variable or column.
# Out:
# pandas.core.series.Series

# %% [markdown]
# ** l. Create a new variable equal to the ratio of Brazil's GDP per capita to Japan's and add it to the DataFrame.**

# %%
weo["BRA_to_JPN"] = weo["BRA"] / weo["JPN"]

# %%
weo
# Out:
#      BRA    JPN    USA    Year  BRA_to_JPN
# 0  13.37  33.43  48.30  2008.0    0.399940
# 1  13.30  31.83  46.91  2009.0    0.417845
# 2  14.34  33.71  48.31  2010.0    0.425393
# 3  15.07  34.29  49.72  2011.0    0.439487
# 4  15.46  35.60  51.41  2012.0    0.434270
# 5  15.98  36.79  52.94  2013.0    0.434357
# 6  16.10  37.39  54.60  2014.0    0.430596

# %% [markdown]
# **m. *Challenging.* Use the ```drop()``` method to eliminate this (new) variable from the dataframe.**

# %%
weo = weo.drop(["BRA_to_JPN"], axis = 1)

# %%
weo
# Out:
#      BRA    JPN    USA    Year
# 0  13.37  33.43  48.30  2008.0
# 1  13.30  31.83  46.91  2009.0
# 2  14.34  33.71  48.31  2010.0
# 3  15.07  34.29  49.72  2011.0
# 4  15.46  35.60  51.41  2012.0
# 5  15.98  36.79  52.94  2013.0
# 6  16.10  37.39  54.60  2014.0

# %% [markdown]
# **n. What are weo's row and column labels?**

# %%
weo.index.tolist() # These are weo's row labels.
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
weo.columns.tolist() # These are weo's column labels.
# Out:
# ['BRA', 'JPN', 'USA', 'Year']

# %% [markdown]
# **o. Set the index equal to the Year variable.**

# %%
weo = weo.set_index("Year")

# %%
weo
# Out:
#           BRA    JPN    USA
# Year
# 2008.0  13.37  33.43  48.30
# 2009.0  13.30  31.83  46.91
# 2010.0  14.34  33.71  48.31
# 2011.0  15.07  34.29  49.72
# 2012.0  15.46  35.60  51.41
# 2013.0  15.98  36.79  52.94
# 2014.0  16.10  37.39  54.60

# %% [markdown]
# **p. Change the names of the other variables to Brazil, Japan, and United States.**

# %%
weo = weo.rename(columns={'BRA': 'Brazil', 'JPN': 'Japan', 'USA': 'United States'})

# %%
weo
# Out:
#         Brazil  Japan  United States
# Year
# 2008.0   13.37  33.43          48.30
# 2009.0   13.30  31.83          46.91
# 2010.0   14.34  33.71          48.31
# 2011.0   15.07  34.29          49.72
# 2012.0   15.46  35.60          51.41
# 2013.0   15.98  36.79          52.94
# 2014.0   16.10  37.39          54.60

# %% [markdown]
# **q. Export the dataframe to an Excel spreadsheet.**

# %%
weo.to_excel('C:/Users/Esther Chao/Desktop/CodePractice1.xlsx')

# %% [markdown]
# **r. What method would you use to compute the mean for each country? What are the means?**

# %%
weo.mean()
# Out:
# Brazil           14.802857
# Japan            34.720000
# United States    50.312857
# dtype: float64

# %% [markdown]
# **s. *Challenging.* How would you compute means across countries for each year?**

# %%
weo.transpose()
# Out:
# Year           2008.0  2009.0  2010.0  2011.0  2012.0  2013.0  2014.0
# Brazil          13.37   13.30   14.34   15.07   15.46   15.98   16.10
# Japan           33.43   31.83   33.71   34.29   35.60   36.79   37.39
# United States   48.30   46.91   48.31   49.72   51.41   52.94   54.60

# %%
weo.transpose().mean()
# Out:
# Year
# 2008.0    31.700000
# 2009.0    30.680000
# 2010.0    32.120000
# 2011.0    33.026667
# 2012.0    34.156667
# 2013.0    35.236667
# 2014.0    36.030000
# dtype: float64

# %% [markdown]
# **t. Plot the data by applying a plot method to weo.**

# %%
import matplotlib.pyplot as plt

# %%
weo.plot()

plt.show()

# %% [markdown]
# **u. *Challenging.* Change the colors of the lines to green (Brazil), red (Japan), and blue (US).**

# %%
weo.plot(color = ['green', 'red', 'blue'])

plt.show()

# %% [markdown]
# **v. *Challenging.* Do the same plot with a log scale. *Hint:* Read the documentation for the plot method.**

# %%
weo.plot?

# %%
weo.plot(logy = True)

plt.show()

# %% [markdown]
# **w. Plot Brazil on its own.**

# %%
weo['Brazil'].plot()

plt.show()

# %% [markdown]
# ### 2. Use read_csv() to read the responses of a previous semesters entry poll.

# %% [markdown]
# **a. Read the file and assign it to the variable ep.**

# %%
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp/'
url2 = 'Materials/master/Data/entry_poll_fall16.csv'

url = url1 + url2

ep = pd.read_csv(url)

# %% [markdown]
# **b. Describe its contents. What are the variables? The responses?**

# %%
ep.shape # There are 85 rows and 10 columns.
# Out:
# (85, 10)

# %%
ep.columns.tolist() # These are the variables.
# Out:
# ['TimeStamp',
#  'Why have you enrolled in this course?  ',
#  'What program are you enrolled in?',
#  'How much programming experience have you had?',
#  'How much experience with probability and statistics have you had?',
#  'What is your expected major or concentration? ',
#  'What career path most interests you? ',
#  'Do you use social media for information purposes?  Check all that apply.',
#  'What kinds of data most interest you?  List any that cross your mind.  ',
#  'If we have time -- and we may not -- what special topics would interest you?  Check all that apply.']

# %% [markdown]
# The responses are the answers to the survey from a previous semester - all varied and strings.

# %% [markdown]
# **c. What data types are the variables?**

# %%
ep.dtypes
# Out:
# TimeStamp                                                                                              object
# Why have you enrolled in this course?                                                                  object
# What program are you enrolled in?                                                                      object
# How much programming experience have you had?                                                          object
# How much experience with probability and statistics have you had?                                      object
# What is your expected major or concentration?                                                          object
# What career path most interests you?                                                                   object
# Do you use social media for information purposes?  Check all that apply.                               object
# ...

# %% [markdown]
# All of the reponses are objects, meaning they are probably strings. Pandas refers to anything that's not a float or interger as an object.

# %% [markdown]
# **d. Change the variable names to something shorter.**

# %%
ep.columns = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8', 'Q9', 'Q10']

# %%
ep.columns.tolist()
# Out:
# ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8', 'Q9', 'Q10']

# %% [markdown]
# **e. *Challenging.* Describe what this code does: ```ep[list(ep)[1]].value_counts()```. *Suggestion:* Break it into two or more statements and explain them one at a time.**

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# I code/build websites in my spare time as a hobby     1
# i am living in Santiago de Chile                      1
# Recommended by a professor.                           1
# Wanted to try something completely different          1
# I like a challenge                                    1
# To finish my major                                    1
# Name: Q2, dtype: int64

# %%
list(ep) # This statement lists only the variables of the DataFrame.
# Out:
# ['TimeStamp',
#  'Why have you enrolled in this course?  ',
#  'What program are you enrolled in?',
#  'How much programming experience have you had?',
#  'How much experience with probability and statistics have you had?',
#  'What is your expected major or concentration? ',
#  'What career path most interests you? ',
#  'Do you use social media for information purposes?  Check all that apply.',
#  'What kinds of data most interest you?  List any that cross your mind.  ',
#  'If we have time -- and we may not -- what special topics would interest you?  Check all that apply.']

# %%
list(ep)[1] # Adding [1] to the above statement slices the second variable.
# Out:
# 'Why have you enrolled in this course?  '

# %%
ep[list(ep)[1]] # Surrounding the above statement with ep[] extracts all the responses of that variable's column.
# Out:
# 0                                To help with my career
# 1                                    I heard it was fun
# 2                                    I like a challenge
# 3                                    I heard it was fun
# 4                                    I heard it was fun
# 5                                    I heard it was fun
# 6                                To help with my career
# 7                                To help with my career
# 8                           I lost my mind for a minute
# 9                                    I heard it was fun
# 10                               To help with my career
# 11                               To help with my career
# 12                               To help with my career
# 13                                   I heard it was fun
# 14    I code/build websites in my spare time as a hobby
# 15                               To help with my career
# 16                          I lost my mind for a minute
# ...

# %%
ep[list(ep)[1]].value_counts() # Finally, adding .value_counts() counts the number of times each response appears in that column.
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# Wanted to try something completely different          1
# I like a challenge                                    1
# I code/build websites in my spare time as a hobby     1
# To finish my major                                    1
# i am living in Santiago de Chile                      1
# Recommended by a professor.                           1
# Name: Why have you enrolled in this course?  , dtype: int64

# %% [markdown]
# ### 3. Consider the 538 college majors data at url:

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2

# %% [markdown]
# **a. Create a dataframe df538 from the csv file at url using ```read_csv()```. What are its dimensions?**

# %%
df538 = pd.read_csv(url)

# %%
df538.shape # It has 173 rows and 21 columns.
# Out:
# (173, 21)

# %% [markdown]
# **b. What argument/parameter would you use to read only the first ten lines of the file?**

# %%
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# ** c. Extract the variables numbered [2, 4, 15, 16, 17]. What are the names of these variables? What do they represent?**

# %%
df538[[2, 4, 15, 16, 17]] # Extracting columns by calling their number no longer works in this version.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-9db2e2026c70> in <module>()
# ----> 1 df538[[2, 4, 15, 16, 17]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ...

# %%
df538.columns[[2, 4, 15, 16, 17]] # These are the names of the variables.
# Out:
# Index(['Major', 'Men', 'Median', 'P25th', 'P75th'], dtype='object')

# %% [markdown]
# "Major" is the name of the major. "Men" is the mean. "Median" is the median. "P25th" is the 25th percentile. P75th is the 75th percentile.

# %%
df538[['Major', 'Men', 'Median', 'P25th', 'P75th']] # Using the variable names instead, we can extract the columns.
# Out:
#                                              Major      Men  Median  P25th  \
# 0                            PETROLEUM ENGINEERING   2057.0  110000  95000
# 1                   MINING AND MINERAL ENGINEERING    679.0   75000  55000
# 2                        METALLURGICAL ENGINEERING    725.0   73000  50000
# 3        NAVAL ARCHITECTURE AND MARINE ENGINEERING   1123.0   70000  43000
# 4                             CHEMICAL ENGINEERING  21239.0   65000  50000
# 5                              NUCLEAR ENGINEERING   2200.0   65000  50000
# 6                                ACTUARIAL SCIENCE   2110.0   62000  53000
# 7                       ASTRONOMY AND ASTROPHYSICS    832.0   62000  31500
# 8                           MECHANICAL ENGINEERING  80320.0   60000  48000
# 9                           ELECTRICAL ENGINEERING  65511.0   60000  45000
# 10                            COMPUTER ENGINEERING  33258.0   60000  45000
# ...

# %% [markdown]
# **d. Set the index equal to Major.**

# %%
df538 = df538.set_index("Major")

# %%
df538
# Out:
#                                                Rank  Major_code     Total  \
# Major
# PETROLEUM ENGINEERING                             1        2419    2339.0
# MINING AND MINERAL ENGINEERING                    2        2416     756.0
# METALLURGICAL ENGINEERING                         3        2415     856.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         4        2417    1258.0
# CHEMICAL ENGINEERING                              5        2405   32260.0
# NUCLEAR ENGINEERING                               6        2418    2573.0
# ACTUARIAL SCIENCE                                 7        6202    3777.0
# ASTRONOMY AND ASTROPHYSICS                        8        5001    1792.0
# MECHANICAL ENGINEERING                            9        2414   91227.0
# ELECTRICAL ENGINEERING                           10        2408   81527.0
# COMPUTER ENGINEERING                             11        2407   41542.0
# AEROSPACE ENGINEERING                            12        2401   15058.0
# ...

# %% [markdown]
# **e. Use the sort_values() method to sort the data by Total.**

# %%
df538_sort = df538.sort_values("Total")

# %%
df538_sort
# Out:
#                                                     Rank  Major_code  \
# Major
# MILITARY TECHNOLOGIES                                 74        3801
# MATHEMATICS AND COMPUTER SCIENCE                      53        4005
# SOIL SCIENCE                                         113        1106
# GEOLOGICAL AND GEOPHYSICAL ENGINEERING                34        2411
# MINING AND MINERAL ENGINEERING                         2        2416
# EDUCATIONAL ADMINISTRATION AND SUPERVISION           121        2301
# SCHOOL STUDENT COUNSELING                             56        2303
# METALLURGICAL ENGINEERING                              3        2415
# LIBRARY SCIENCE                                      173        3501
# COURT REPORTING                                       20        3201
# NAVAL ARCHITECTURE AND MARINE ENGINEERING              4        2417
# BOTANY                                                84        3602
# ...

# %% [markdown]
# **f. What code would you use to extract the ten majors with the greatest number of people?**

# %%
df538_most = df538.sort_values("Total", ascending = False).head(10) 

# I used head(10) & descending instead of tail(10) & ascending because NaN was included when sorting by ascending.

# %%
df538_most
# Out:
#                                         Rank  Major_code     Total       Men  \
# Major
# PSYCHOLOGY                               146        5200  393735.0   86648.0
# BUSINESS MANAGEMENT AND ADMINISTRATION    77        6203  329927.0  173809.0
# BIOLOGY                                  124        3600  280709.0  111762.0
# GENERAL BUSINESS                          58        6200  234590.0  132238.0
# COMMUNICATIONS                            94        1901  213996.0   70619.0
# NURSING                                   35        6107  209394.0   21773.0
# MARKETING AND MARKETING RESEARCH          78        6206  205211.0   78857.0
# ACCOUNTING                                41        6201  198633.0   94519.0
# ENGLISH LANGUAGE AND LITERATURE          138        3301  194673.0   58227.0
# POLITICAL SCIENCE AND GOVERNMENT          79        5506  182621.0   93880.0
#
#                                            Women               Major_category  \
# Major
# ...

# %% [markdown]
# **g. *Challenging.* Construct horizontal bar charts of the top ten majors sorted, first, by median salary and, second, by the salary of the 25th percentile. In each case, plot just the variable you sorted on.**

# %%
import matplotlib.pyplot as plt

# %%
df538_most.sort_values('Median', ascending = False).Median.plot(kind = "bar") 

# Since it wasn't specified, I chose to sort by descending because it made more sense to me.

plt.show()

# %%
df538_most.sort_values('P25th', ascending = False).P25th.plot(kind = "bar")

# Since it wasn't specified, I chose to sort by descending because it made more sense to me.

plt.show()
